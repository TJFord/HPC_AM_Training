# %%
import matplotlib.pyplot as plt
import numpy as np

matrix_size = np.array([1024, 2048, 4096]) # matrix size
proc_size = np.array([1, 2, 4]) # number of processors
time = np.array([115.845949, 153.804412, 37.345182]) # seconds

plt.plot(proc_size,time,'s-')
